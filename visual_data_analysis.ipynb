# %% [markdown]
# # Visual Data Analysis of Fraudulent Transactions
#
# Your CFO has also requested detailed trends data on specific card holders. Use the starter notebook to query your database and generate visualizations that supply the requested information as follows, then add your visualizations and observations to your markdown report.

# %%
# Initial imports
import pandas as pd
import calendar
import hvplot.pandas
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os
import urllib.parse

# %%
# Create a connection to the database
load_dotenv('/Users/vishnuvardhan/Documents/Fintech/API.env')
Postg_key=os.getenv("POSTG")
encoded_password = urllib.parse.quote(Postg_key, safe='')
engine = create_engine(f"postgresql://postgres:{encoded_password}@localhost:5432/fintech")

# %% [markdown]
# ## Data Analysis Question 1
#
# The two most important customers of the firm may have been hacked. Verify if there are any fraudulent transactions in their history. For privacy reasons, you only know that their cardholder IDs are 2 and 18.
#
# * Using hvPlot, create a line plot representing the time series of transactions over the course of the year for each cardholder separately.
#
# * Next, to better compare their patterns, create a single line plot that containins both card holders' trend data.
#
# * What difference do you observe between the consumption patterns? Does the difference suggest a fraudulent transaction? Explain your rationale in the markdown report.

# %%
# loading data for card holder 2 and 18 from the database
# Write the query
query = '''
SELECT * FROM public.transaction_view where cardholder_id =18 or cardholder_id =2;
'''
# Create a DataFrame from the query result. HINT: Use pd.read_sql(query, engine)
transactions_df = pd.read_sql(query, engine)

display(transactions_df)
# Out:
#      transaction_id    transaction_date  transaction_amount  \
# 0               567 2018-01-01 23:15:10                2.95
# 1              2077 2018-01-05 07:19:27                1.36
# 2              2439 2018-01-06 02:16:41                1.33
# 3              1867 2018-01-06 05:13:20               10.82
# 4              3457 2018-01-07 01:10:54              175.00
# ..              ...                 ...                 ...
# 227            1994 2018-12-27 18:46:57                1.70
# 228             114 2018-12-28 08:45:26                3.46
# 229            1228 2018-12-28 09:00:45               12.88
# 230             962 2018-12-28 15:30:55               11.03
# 231            1218 2018-12-29 08:11:55               12.25
#
#       credit_card_number  cardholder_id
# 0          4498002758300             18
# 1        344119623920892             18
# 2    4866761290278198714              2
# 3    4866761290278198714              2
# ...

# %%
transactions_df['transaction_date'] = pd.to_datetime(transactions_df['transaction_date'])
transactions_df.set_index('transaction_date', inplace=True)

transactions_df
# Out:
#                      transaction_id  transaction_amount   credit_card_number  \
# transaction_date
# 2018-01-01 23:15:10             567                2.95        4498002758300
# 2018-01-05 07:19:27            2077                1.36      344119623920892
# 2018-01-06 02:16:41            2439                1.33  4866761290278198714
# 2018-01-06 05:13:20            1867               10.82  4866761290278198714
# 2018-01-07 01:10:54            3457              175.00      344119623920892
# ...                             ...                 ...                  ...
# 2018-12-27 18:46:57            1994                1.70      344119623920892
# 2018-12-28 08:45:26             114                3.46        4498002758300
# 2018-12-28 09:00:45            1228               12.88      344119623920892
# 2018-12-28 15:30:55             962               11.03         675911140852
# 2018-12-29 08:11:55            1218               12.25        4498002758300
#
# ...

# %%
# Plot for cardholder 2
import hvplot.pandas
transactions_df.hvplot.line(x='transaction_date',y='transaction_amount',groupby='cardholder_id')
# Out:
# :DynamicMap   [cardholder_id]
#    :Curve   [transaction_date]   (transaction_amount)

# %%
# Plot for cardholder 18
transactions_df.hvplot.line(x='transaction_date',y='transaction_amount',groupby='cardholder_id')
# Out:
# :DynamicMap   [cardholder_id]
#    :Curve   [transaction_date]   (transaction_amount)

# %%
# Combined plot for card holders 2 and 18
transactions_df.hvplot.line(x='transaction_date',y='transaction_amount',by="cardholder_id")
# Out:
# :NdOverlay   [cardholder_id]
#    :Curve   [transaction_date]   (transaction_amount)

# %% [markdown]
# ## Data Analysis Question 2
#
# The CEO of the biggest customer of the firm suspects that someone has used her corporate credit card without authorization in the first quarter of 2018 to pay quite expensive restaurant bills. Again, for privacy reasons, you know only that the cardholder ID in question is 25.
#
# * Using hvPlot, create a box plot, representing the expenditure data from January 2018 to June 2018 for cardholder ID 25.
#
# * Are there any outliers for cardholder ID 25? How many outliers are there per month?
#
# * Do you notice any anomalies? Describe your observations and conclusions in your markdown report.

# %%
# loading data of daily transactions from jan to jun 2018 for card holder 25
# Write the query
query2 = """
SELECT *
FROM transaction_view
WHERE cardholder_id = 25
AND transaction_date >= '2018-01-01'
AND transaction_date < '2018-07-01';
        """
# Create a DataFrame from the query result. HINT: Use pd.read_sql(query, engine)
transactions_df_2 = pd.read_sql(query2, engine)
transactions_df_2
# Out:
#     transaction_id    transaction_date  transaction_amount credit_card_number  \
# 0             2083 2018-01-02 02:06:21                1.46      4319653513507
# 1             1552 2018-01-05 06:26:45               10.74    372414832802279
# 2             2108 2018-01-07 14:57:23                2.93      4319653513507
# 3              754 2018-01-10 00:25:40                1.39    372414832802279
# 4             3023 2018-01-14 05:02:22               17.84    372414832802279
# ..             ...                 ...                 ...                ...
# 63            2582 2018-06-22 06:16:50             1813.00      4319653513507
# 64            3218 2018-06-23 22:36:00               16.61      4319653513507
# 65            1523 2018-06-25 09:17:05               11.53    372414832802279
# 66            2264 2018-06-27 14:33:06                5.24    372414832802279
# 67             671 2018-06-30 03:05:55                2.27    372414832802279
#
#     cardholder_id
# ...

# %%
# loop to change the numeric month to month names
transactions_df_2['transaction_date'] = pd.to_datetime(transactions_df_2['transaction_date'])
transactions_df_2['transaction_month'] = transactions_df_2['transaction_date'].dt.month_name()
transactions_df_2.set_index('transaction_month', inplace=True)
transactions_df_2=
# Out:
#                    transaction_id    transaction_date  transaction_amount  \
# transaction_month
# January                      2083 2018-01-02 02:06:21                1.46
# January                      1552 2018-01-05 06:26:45               10.74
# January                      2108 2018-01-07 14:57:23                2.93
# January                       754 2018-01-10 00:25:40                1.39
# January                      3023 2018-01-14 05:02:22               17.84
# ...                           ...                 ...                 ...
# June                         2582 2018-06-22 06:16:50             1813.00
# June                         3218 2018-06-23 22:36:00               16.61
# June                         1523 2018-06-25 09:17:05               11.53
# June                         2264 2018-06-27 14:33:06                5.24
# June                          671 2018-06-30 03:05:55                2.27
#
#                   credit_card_number  cardholder_id
# ...

# %%
# Creating the six box plots using hvPlot
transactions_df_2.hvplot.box(
    y='transaction_amount',
    by='transaction_month',
    xlabel='Months',
    ylabel='Transaction Amount',
    title='Expenditure Data from January 2018 to June 2018 for Cardholder ID 25',
)
# Out:
# :BoxWhisker   [transaction_month]   (transaction_amount)
